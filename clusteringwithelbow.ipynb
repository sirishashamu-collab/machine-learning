# %%
import pandas as pd

df = pd.read_excel(r"C:\Users\HP\Downloads\EXL Shared Partner Data.xlsx")
print(df.head(2))
# Out:
#   Application_Nr QuoteGeneratedDate  OfferCoverageAmount Offer_Stat_Desc  \
# 0   CUNA11261506         2018-02-07                15000            Void
# 1   CUNA11263501         2018-02-08                10000          Signed
#
#    OfferPremiumAmount OfferBillingMethod Pmnt_Freq_Desc Effective_Date  \
# 0               13.75        Credit Card        Monthly            NaT
# 1               74.80        Credit Card        Monthly     2018-02-08
#
#   Paid_To_Date  Offered_NAP  Issued_NAP CurrentBillMethod     ProductType  \
# 0          NaT        165.0         NaN               NaN  SI Term Band 1
# 1   2022-09-08        897.6       897.6               PAC   SI Whole Life
#
#    Age_at_AppReceived PartnerMarker
# 0                53.0       Liberty
# 1                70.0       Liberty

# %%
df.head(2)
# Out:
#   Application_Nr QuoteGeneratedDate  OfferCoverageAmount Offer_Stat_Desc  \
# 0   CUNA11261506         2018-02-07                15000            Void
# 1   CUNA11263501         2018-02-08                10000          Signed
#
#    OfferPremiumAmount OfferBillingMethod Pmnt_Freq_Desc Effective_Date  \
# 0               13.75        Credit Card        Monthly            NaT
# 1               74.80        Credit Card        Monthly     2018-02-08
#
#   Paid_To_Date  Offered_NAP  Issued_NAP CurrentBillMethod     ProductType  \
# 0          NaT        165.0         NaN               NaN  SI Term Band 1
# 1   2022-09-08        897.6       897.6               PAC   SI Whole Life
#
#    Age_at_AppReceived PartnerMarker Quote_Year_month Quote_Year
# 0                53.0       Liberty          2018-02       2018
# 1                70.0       Liberty          2018-02       2018

# %%
df.tail(2)
# Out:
#        Application_Nr QuoteGeneratedDate  OfferCoverageAmount  \
# 458870   CUNA17318525         2022-09-07                80000
# 458871   CUNA17318599         2022-09-07                30000
#
#          Offer_Stat_Desc  OfferPremiumAmount OfferBillingMethod  \
# 458870  Lapsed Abandoned                89.4            ACH/PAC
# 458871  Lapsed Abandoned               294.3            ACH/PAC
#
#        Pmnt_Freq_Desc Effective_Date Paid_To_Date  Offered_NAP  Issued_NAP  \
# 458870        Monthly            NaT          NaT       1072.8         NaN
# 458871        Monthly            NaT          NaT       3531.6         NaN
#
#        CurrentBillMethod ProductType  Age_at_AppReceived PartnerMarker  \
# 458870               NaN        TAWL                32.0       Liberty
# 458871               NaN        TAWL                 NaN       Liberty
#
#        Quote_Year_month Quote_Year
# 458870          2022-09       2022
# 458871          2022-09       2022

# %%
df.shape
# Out:
# (458862, 17)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 458862 entries, 0 to 458871
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Application_Nr       458862 non-null  str
#  1   QuoteGeneratedDate   458862 non-null  datetime64[us]
#  2   OfferCoverageAmount  458862 non-null  int64
#  3   Offer_Stat_Desc      458862 non-null  str
#  4   OfferPremiumAmount   458862 non-null  float64
#  5   OfferBillingMethod   458862 non-null  str
#  6   Pmnt_Freq_Desc       458822 non-null  str
#  7   Effective_Date       190605 non-null  datetime64[us]
#  8   Paid_To_Date         190605 non-null  datetime64[us]
#  9   Offered_NAP          458862 non-null  float64
#  10  Issued_NAP           190605 non-null  float64
#  11  CurrentBillMethod    190605 non-null  str
#  12  ProductType          458852 non-null  str
#  13  Age_at_AppReceived   400627 non-null  float64
#  14  PartnerMarker        458862 non-null  str
#  15  Quote_Year_month     458862 non-null  str
#  16  Quote_Year           458862 non-null  str
# dtypes: datetime64[us](3), float64(4), int64(1), str(9)
# memory usage: 63.0 MB

# %%
df.describe()
# Out:
#                QuoteGeneratedDate  OfferCoverageAmount  OfferPremiumAmount  \
# count                      458862        458862.000000       458862.000000
# mean   2021-05-29 14:56:00.351477         41713.678622           75.454081
# min           2018-02-07 00:00:00          1000.000000            0.000000
# 25%           2020-12-02 00:00:00         10000.000000           40.500000
# 50%           2021-07-19 00:00:00         20000.000000           57.300000
# 75%           2022-02-03 00:00:00         45000.000000           90.700000
# max           2022-09-07 00:00:00        300000.000000         5124.000000
# std                           NaN         61338.618720           68.232560
#
#                    Effective_Date                Paid_To_Date    Offered_NAP  \
# count                      190605                      190605  458862.000000
# mean   2021-05-09 20:43:12.611946  2021-12-18 12:22:37.840559     891.690270
# min           2018-02-08 00:00:00         2018-02-13 00:00:00       0.000000
# 25%           2020-10-17 00:00:00         2021-06-15 00:00:00     485.280000
# 50%           2021-06-24 00:00:00         2022-04-01 00:00:00     684.960000
# 75%           2022-01-10 00:00:00         2022-09-19 00:00:00    1081.200000
# max           2022-11-01 00:00:00         2024-05-01 00:00:00   14496.000000
# std                           NaN                         NaN     709.775197
#
#           Issued_NAP  Age_at_AppReceived
# count  190605.000000       400627.000000
# mean      864.271308           55.467078
# min         0.000000           17.000000
# 25%       462.000000           48.000000
# 50%       682.680000           58.000000
# 75%      1077.600000           65.000000
# max     14496.000000           96.000000
# std       663.639863           13.235514

# %%
df.shape
# Out:
# (458862, 17)

# %%
from datetime import datetime
df['Quote_Year_month'] = df['QuoteGeneratedDate'].apply(lambda x: datetime.strftime(x, '%Y-%m'))

# %%
df['Quote_Year'] = df['QuoteGeneratedDate'].apply(lambda x: datetime.strftime(x, '%Y'))

# %%
df.head(2)
# Out:
#   Application_Nr QuoteGeneratedDate  OfferCoverageAmount Offer_Stat_Desc  \
# 0   CUNA11261506         2018-02-07                15000            Void
# 1   CUNA11263501         2018-02-08                10000          Signed
#
#    OfferPremiumAmount OfferBillingMethod Pmnt_Freq_Desc Effective_Date  \
# 0               13.75        Credit Card        Monthly            NaT
# 1               74.80        Credit Card        Monthly     2018-02-08
#
#   Paid_To_Date  Offered_NAP  Issued_NAP CurrentBillMethod     ProductType  \
# 0          NaT        165.0         NaN               NaN  SI Term Band 1
# 1   2022-09-08        897.6       897.6               PAC   SI Whole Life
#
#    Age_at_AppReceived PartnerMarker Quote_Year_month Quote_Year
# 0                53.0       Liberty          2018-02       2018
# 1                70.0       Liberty          2018-02       2018

# %%
data = df.groupby(['Quote_Year'])['OfferCoverageAmount'].sum().reset_index(name="coverage_sum")

# %%
data
# Out:
#   Quote_Year  coverage_sum
# 0       2018     179392000
# 1       2019    1096199000
# 2       2020    2505099000
# 3       2021    7213646000
# 4       2022    8146486000

# %%
data_month = df.groupby(['Quote_Year_month'])['OfferCoverageAmount'].sum().reset_index(name="coverage_sum")

# %%
data_month.head()
# Out:
#   Quote_Year_month  coverage_sum
# 0          2018-02       3379000
# 1          2018-03       7988000
# 2          2018-04       6284000
# 3          2018-05       6705000
# 4          2018-06       6586000

# %%
data_month.shape
# Out:
# (56, 2)

# %%
import seaborn as sns

# %%
sns.barplot(data=data_month, x='Quote_Year_month', y='coverage_sum')
# Out:
# <Axes: xlabel='Quote_Year_month', ylabel='coverage_sum'>

# %%
data.head(5)
# Out:
#   Quote_Year  coverage_sum
# 0       2018     179392000
# 1       2019    1096232000
# 2       2020    2505178000
# 3       2021    7213646000
# 4       2022    8146486000

# %%
df.head()
# Out:
#   Application_Nr QuoteGeneratedDate  OfferCoverageAmount Offer_Stat_Desc  \
# 0   CUNA11261506         2018-02-07                15000            Void
# 1   CUNA11263501         2018-02-08                10000          Signed
# 2   CUNA11264400         2018-02-09                15000          Signed
# 3   CUNA11264436         2018-02-09                15000          Signed
# 4   CUNA11264525         2018-02-09                10000          Signed
#
#    OfferPremiumAmount OfferBillingMethod Pmnt_Freq_Desc Effective_Date  \
# 0               13.75        Credit Card        Monthly            NaT
# 1               74.80        Credit Card        Monthly     2018-02-08
# 2               42.35        Credit Card        Monthly     2018-02-09
# 3               57.05        Credit Card        Monthly     2018-02-09
# 4               27.80            ACH/PAC        Monthly     2018-02-12
#
#   Paid_To_Date  Offered_NAP  Issued_NAP CurrentBillMethod     ProductType  \
# 0          NaT        165.0         NaN               NaN  SI Term Band 1
# 1   2022-09-08        897.6       897.6               PAC   SI Whole Life
# 2   2022-10-09        508.2       508.2               DIR   SI Whole Life
# 3   2022-10-09        684.6       684.6               DIR   SI Whole Life
# 4   2021-02-12        333.6       333.6               PAC  SI Term Band 1
#
#    Age_at_AppReceived PartnerMarker Quote_Year_month Quote_Year
# 0                53.0       Liberty          2018-02       2018
# 1                70.0       Liberty          2018-02       2018
# 2                54.0       Liberty          2018-02       2018
# 3                58.0       Liberty          2018-02       2018
# 4                65.0       Liberty          2018-02       2018

# %%
df = df.dropna(subset=['Application_Nr'])

# %%
df.columns
# Out:
# Index(['Application_Nr', 'QuoteGeneratedDate', 'OfferCoverageAmount',
#        'Offer_Stat_Desc', 'OfferPremiumAmount', 'OfferBillingMethod',
#        'Pmnt_Freq_Desc', 'Effective_Date', 'Paid_To_Date', 'Offered_NAP',
#        'Issued_NAP', 'CurrentBillMethod', 'ProductType', 'Age_at_AppReceived',
#        'PartnerMarker', 'Quote_Year_month', 'Quote_Year'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# Application_Nr              0
# QuoteGeneratedDate          0
# OfferCoverageAmount         0
# Offer_Stat_Desc             0
# OfferPremiumAmount          0
# OfferBillingMethod          0
# Pmnt_Freq_Desc             40
# Effective_Date         268257
# Paid_To_Date           268257
# Offered_NAP                 0
# Issued_NAP             268257
# CurrentBillMethod      268257
# ProductType                10
# Age_at_AppReceived      58235
# PartnerMarker               0
# Quote_Year_month            0
# Quote_Year                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 458862 entries, 0 to 458871
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Application_Nr       458862 non-null  str
#  1   QuoteGeneratedDate   458862 non-null  datetime64[us]
#  2   OfferCoverageAmount  458862 non-null  int64
#  3   Offer_Stat_Desc      458862 non-null  str
#  4   OfferPremiumAmount   458862 non-null  float64
#  5   OfferBillingMethod   458862 non-null  str
#  6   Pmnt_Freq_Desc       458822 non-null  str
#  7   Effective_Date       190605 non-null  datetime64[us]
#  8   Paid_To_Date         190605 non-null  datetime64[us]
#  9   Offered_NAP          458862 non-null  float64
#  10  Issued_NAP           190605 non-null  float64
#  11  CurrentBillMethod    190605 non-null  str
#  12  ProductType          458852 non-null  str
#  13  Age_at_AppReceived   400627 non-null  float64
#  14  PartnerMarker        458862 non-null  str
#  15  Quote_Year_month     458862 non-null  str
#  16  Quote_Year           458862 non-null  str
# dtypes: datetime64[us](3), float64(4), int64(1), str(9)
# memory usage: 63.0 MB

# %%
df.isna().sum()
# Out:
# Application_Nr              0
# QuoteGeneratedDate          0
# OfferCoverageAmount         0
# Offer_Stat_Desc             0
# OfferPremiumAmount          0
# OfferBillingMethod          0
# Pmnt_Freq_Desc             40
# Effective_Date         268257
# Paid_To_Date           268257
# Offered_NAP                 0
# Issued_NAP             268257
# CurrentBillMethod      268257
# ProductType                10
# Age_at_AppReceived      58235
# PartnerMarker               0
# Quote_Year_month            0
# Quote_Year                  0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Quote_Year      0
# coverage_sum    0
# dtype: int64

# %%
def null_values(base_dataset):
    print(base_dataset.isna().sum())
    len(base_dataset.isna().sum().index)
    cont=base_dataset.describe().columns
    print(cont)
    # fetching all column names form from dataframe and trying to filter out some of the column names which we are getting from the base_dataset.describe()
    cat=[i for i in base_dataset.columns if i not in base_dataset.describe().columns] # this is one way of getting categorical column
    # we do have other ways also to get categorical columns
    
    print(cat)
    for i in cat:
        base_dataset[i].fillna(base_dataset[i].value_counts().index[0],inplace=True)
        # fill these null values with the help of mode also
    for i in cont:
        base_dataset[i].fillna(base_dataset[i].median(),inplace=True)
    print(base_dataset.isna().sum())
    return base_dataset,cat,cont
