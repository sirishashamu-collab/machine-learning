# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Suppress Warnings for clean notebook  
#It hides warning messages in your notebook output.
import warnings
warnings.filterwarnings('ignore')

# %%
dataset=pd.read_csv("Melbourne_housing_FULL.csv")

# %%
dataset.head(2)
# Out:
#        Suburb        Address  Rooms Type      Price Method SellerG       Date  \
# 0  Abbotsford  68 Studley St      2    h        NaN     SS  Jellis  3/09/2016
# 1  Abbotsford   85 Turner St      2    h  1480000.0      S  Biggin  3/12/2016
#
#    Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  YearBuilt  \
# 0       2.5    3067.0  ...       1.0  1.0     126.0           NaN        NaN
# 1       2.5    3067.0  ...       1.0  1.0     202.0           NaN        NaN
#
#           CouncilArea Lattitude  Longtitude             Regionname  \
# 0  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
# 1  Yarra City Council  -37.7996    144.9984  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
#
# [2 rows x 21 columns]

# %%
 dataset.tail(2)
# Out:
#            Suburb           Address  Rooms Type      Price Method  \
# 34855  Yarraville  12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 34855  hockingstuart  24/02/2018       6.3    3013.0  ...       NaN  NaN
# 34856             RW  24/02/2018       6.3    3013.0  ...       1.0  0.0
#
#        Landsize  BuildingArea  YearBuilt               CouncilArea Lattitude  \
# 34855       NaN           NaN        NaN  Maribyrnong City Council       NaN
# 34856     250.0         103.0     1930.0  Maribyrnong City Council  -37.8181
#
#        Longtitude            Regionname Propertycount
# 34855         NaN  Western Metropolitan        6543.0
# 34856   144.89351  Western Metropolitan        6543.0
#
# [2 rows x 21 columns]

# %%
dataset.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='str')

# %%
dataset.shape
# Out:
# (34857, 21)

# %%
dataset.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
#dataset.info()

# %%
cols_to_use = ['Suburb', 'Rooms', 'Type', 'Method', 'SellerG', 'Regionname', 'Propertycount', 
               'Distance', 'CouncilArea', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'Price']
dataset = dataset[cols_to_use]

# %%
dataset.head(2)
# Out:
#        Suburb  Rooms Type Method SellerG             Regionname  \
# 0  Abbotsford      2    h     SS  Jellis  Northern Metropolitan
# 1  Abbotsford      2    h      S  Biggin  Northern Metropolitan
#
#    Propertycount  Distance         CouncilArea  Bedroom2  Bathroom  Car  \
# 0         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
# 1         4019.0       2.5  Yarra City Council       2.0       1.0  1.0
#
#    Landsize  BuildingArea      Price
# 0     126.0           NaN        NaN
# 1     202.0           NaN  1480000.0

# %%
dataset.isnull().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        3
# Distance             1
# CouncilArea          3
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
dataset.shape
# Out:
# (34857, 15)

# %%
cols_to_fill_zero=['Propertycount','Distance','Bedroom2', 'Bathroom', 'Car']
dataset[cols_to_fill_zero]=dataset[cols_to_fill_zero].fillna(0)


dataset['Landsize']=dataset['Landsize'].fillna(dataset.Landsize.mean())
dataset['BuildingArea']=dataset['BuildingArea'].fillna(dataset.BuildingArea.mean())

# %%
dataset.isnull().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Regionname          3
# Propertycount       0
# Distance            0
# CouncilArea         3
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# Price            7610
# dtype: int64

# %%
dataset.dropna(inplace=True)
#Rows with any missing value are removed
#If 50% rows have missing values → you lose half dataset
#

# %%
dataset.shape
# Out:
# (27244, 15)

# %%
dataset.isnull().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Price            0
# dtype: int64

# %% [markdown]
# *****Let's one hot encode the categorical features****

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype=float)

# %%
dataset.head(1)
# Out:
#    Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1      2         4019.0       2.5       2.0       1.0  1.0     202.0
#
#    BuildingArea      Price  Suburb_Aberfeldie  ...  \
# 1      160.2564  1480000.0                0.0  ...
#
#    CouncilArea_Moorabool Shire Council  CouncilArea_Moreland City Council  \
# 1                                  0.0                                0.0
#
#    CouncilArea_Nillumbik Shire Council  CouncilArea_Port Phillip City Council  \
# 1                                  0.0                                    0.0
#
#    CouncilArea_Stonnington City Council  CouncilArea_Whitehorse City Council  \
# 1                                   0.0                                  0.0
#
#    CouncilArea_Whittlesea City Council  CouncilArea_Wyndham City Council  \
# 1                                  0.0                               0.0
#
#    CouncilArea_Yarra City Council  CouncilArea_Yarra Ranges Shire Council
# ...

# %%
x=dataset.drop('Price',axis=1)
y=dataset['Price']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(x_train,y_train)

# %% [markdown]
# ****Let's train our Linear Regression Model on training dataset and check the accuracy on test set****

# %%
reg.score(x_test,y_test)
# Out:
# 0.13853683161563934

# %%
reg.score(x_train,y_train)
# Out:
# 0.6827792395792722

# %% [markdown]
# *****Here training score is 68% but test score is 13.85% which is very low
#
# Normal Regression is clearly overfitting the data,
#
# let's try other models
#
#
#
# Using Lasso (L1 Regularized) Regression Model*****

# %%
from sklearn import linear_model
lasso_reg = linear_model.Lasso(alpha=50, max_iter=100, tol=0.1)
lasso_reg.fit(x_train,y_train)
#print(lasso_reg.coef_)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lasso_reg.score(x_test,y_test)
# Out:
# 0.6636111369404489

# %%
lasso_reg.score(x_train,y_train)
# Out:
# 0.6766985624766824

# %%
y_pred = lasso_reg.predict(x_test)

# %%
y_pred
# Out:
# array([1675386.13328946, 1090665.28984345,  885857.08269037, ...,
#         907941.7324018 ,  792220.8275921 , 1201124.42188506],
#       shape=(8174,))

# %%
lasso_diff=pd.DataFrame({"Actual value":y_test,"Predicated value":y_pred})
lasso_diff.head(2)
# Out:
#        Actual value  Predicated value
# 32841     1720000.0      1.675386e+06
# 10813      555000.0      1.090665e+06

# %%
lasso_diff["Error"] = lasso_diff["Actual value"] - lasso_diff["Predicated value"]
lasso_diff.head(5)
# Out:
#        Actual value  Predicated value          Error
# 32841     1720000.0      1.675386e+06   44613.866711
# 10813      555000.0      1.090665e+06 -535665.289843
# 7211       841000.0      8.858571e+05  -44857.082690
# 17799      415000.0      2.946947e+05  120305.305922
# 3397       800000.0      6.598448e+05  140155.197780

# %%
from sklearn import metrics
meansqerr=metrics.mean_squared_error(y_test,y_pred)
meanaberr=metrics.mean_absolute_error(y_test,y_pred)
rootsqarr=np.sqrt(metrics.mean_squared_error(y_test,y_pred))
print("r sq: {:.2f}".format(lasso_reg.score(x,y)*100))
print("mean sqaure",meansqerr)
print("mean absoulte",meanaberr)
print("root sqaure",rootsqarr)
# Out:
# r sq: 67.29
# mean sqaure 133653603705.6428
# mean absoulte 236924.54916510652
# root sqaure 365586.65690317913

# %%
from sklearn.linear_model import Ridge
ridge_reg= Ridge(alpha=50, max_iter=100, tol=0.1)
ridge_reg.fit(x_train,y_train)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
ridge_reg.score(x_test,y_test)
# Out:
# 0.6670848945194956

# %%
ridge_reg.score(x_train,y_train)
# Out:
# 0.6622376739684328
